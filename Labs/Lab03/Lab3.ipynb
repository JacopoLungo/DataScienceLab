# %% [markdown]
# # Lab #3
# In this laboratory, you will learn more about frequent itemsets and association rules.

# %% [markdown]
# ## Online Retail Data set
# The Online Retail Data Set [1] is a dataset made available on the UCI Machine Learning repository. It which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based online retail.
#
# https://github.com/dbdmg/data-science-lab/raw/master/datasets/online_retail.csv
#
# Each of the 541,909 rows contains an item that has been purchased by someone. Items can be grouped into invoices (you can think of these as receipts), where each invoice has been issued for a specific buyer, and can contain multiple items.
# The columns contained in the CSV file are the following:
# - InvoiceNo: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'C’, it indicates a cancellation.
# - StockCode: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.
# - Description: Product (item) name. Nominal.
# - Quantity: The quantities of each product (item) per transaction. Numeric.
# - InvoiceDate: Invice Date and time. Numeric, the day and time when each transaction was generated.
# - UnitPrice: Unit price. Numeric, Product price per unit in sterling.
# - CustomerID: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.
# - Country: Country name. Nominal, the name of the country where each customer resides.

# %% [markdown]
# ### Association rules from frequent itemses
#
# **1 - Loading and cleaning the dataset**
#
# Loading the dataset and removing invalid rows and those having an InvoiceNo that starts with "C", as they indicate that the invoice is about a cancelled purchase.

# %%
import pandas as pd
import re
import csv

# %%
with open ("online_retail.csv") as f:
    reader = csv.reader(f)
    HretailDs=list(reader)
    
headers=HretailDs[0]
wholeRetailDs=HretailDs[1:]

# %%
#Removing all the rows that has the invoice attribute that start with "C"
#Removingo other errors in the dataset
retailDs = []
for row in wholeRetailDs:
    if not row[0].startswith('C') and not re.search("(?=.*[a-z])|^\\s*$|^\\?", row[2].strip()):#tolgo tutti quelli che iniziano per C o che hanno delle minuscole
        retailDs.append(row)
len(retailDs)
# Out:
# 528464

# %% [markdown]
# **2 - Aggregate at "invoice" level.**
#
# Now that you have a dataset of items, you should aggregate it at an “invoice” level. For each invoice (identified by InvoiceNo) there can be multiple items (from multiple rows) in the dataset. For each invoice, you should build a list of all items belonging to it.

# %%
#Creating a dict to associate all the rows with the same InvoiceNo
tmpDict = {}
for row in retailDs:
    if (row[0] in tmpDict.keys()):
        tmpDict[row[0]].append(row[2].strip())
    else:
        tmpDict[row[0]]=[row[2].strip()]
invoices = list(tmpDict.values())
invoices[0]
# Out:
# ['WHITE HANGING HEART T-LIGHT HOLDER',
#  'WHITE METAL LANTERN',
#  'CREAM CUPID HEARTS COAT HANGER',
#  'KNITTED UNION FLAG HOT WATER BOTTLE',
#  'RED WOOLLY HOTTIE WHITE HEART.',
#  'SET 7 BABUSHKA NESTING BOXES',
#  'GLASS STAR FROSTED T-LIGHT HOLDER']

# %%
#Test of the previous function
diz = {}
lProva = [[5,'a'],[5,'b'],[7,'z']]
print("Transactions:")
[print(el) for el in lProva]

for row in lProva:
    if (row[0] in diz.keys()):
        diz[row[0]].append(row[1])
    else:
        diz[row[0]]=[row[1]]
print("\nAggregated transactions:")
[print(k,v) for k,v in diz.items()]
provaInvoices = list(diz.values())
# Out:
# Transactions:
# [5, 'a']
# [5, 'b']
# [7, 'z']
#
# Aggregated transactions:
# 5 ['a', 'b']
# 7 ['z']

# %% [markdown]
# **3 - Converting the list of invoices into a matrix**
#
# You should now have a list (one for each invoice) of lists (each list containing the items bought for that invoice). Now, we need to convert this into a matrix form. Of the many possible formats, we will use the one expected by the Mlxtend library, which is as follows. Given an ordered list of M possible items (in this case, all possible products that can be bought), and given N itemsets (in this case, invoices), we should build a matrix of N rows and M columns. The element at the ith row and jth column should be 1 if the $i^{th}$ itemset (invoice) contains the $j^{th}$ item (product), 0 otherwise.

# %%
#input: a list of invoices, each invoices is a list that contains a set of items
#output: a matrix of 0(item is absent) and 1(item is present)
def matrixation(invoices):
    linvoices=[x for l in invoices for x in l]
    sortedUniqueItemsList=sorted(list(set(linvoices)))
    matrix=[]
    for row in invoices:
        tmpL=[False]*len(sortedUniqueItemsList)
        for el in row:
            tmpL[sortedUniqueItemsList.index(el)]=True
        matrix.append(tmpL)
    return (sortedUniqueItemsList, matrix)

# %%
#Turing the matrix in a pandas DataFrame
all_items = matrixation(invoices)[0]
pa_matrix = matrixation(invoices)[1]
df = pd.DataFrame(data=pa_matrix, columns=all_items)

# %%
all_items[:10]
# Out:
# ['10 COLOUR SPACEBOY PEN',
#  '12 COLOURED PARTY BALLOONS',
#  '12 DAISY PEGS IN WOOD BOX',
#  '12 EGG HOUSE PAINTED WOOD',
#  '12 HANGING EGGS HAND PAINTED',
#  '12 IVORY ROSE PEG PLACE SETTINGS',
#  '12 MESSAGE CARDS WITH ENVELOPES',
#  '12 PENCIL SMALL TUBE WOODLAND',
#  '12 PENCILS SMALL TUBE RED RETROSPOT',
#  '12 PENCILS SMALL TUBE SKULL']

# %%
#Test of matrixation function
prova = [['a','b','c'],['b','c'],['a','c','d'],['a','b']]
print (prova)
matrixation(prova)
# Out:
# [['a', 'b', 'c'], ['b', 'c'], ['a', 'c', 'd'], ['a', 'b']]
# (['a', 'b', 'c', 'd'],
#  [[True, True, True, False],
#   [False, True, True, False],
#   [True, False, True, True],
#   [True, True, False, False]])

# %% [markdown]
# **4 - Application of the *fp_growth* function**
#
# With the df that you defined in the previous exercise, you can now use the fp_growth function. The first argument required is the previously built DataFrame, df. The second is the minimum support (minsup), i.e. the minimum fraction of the entire dataset in which the itemset should show up for it to be considered “frequent”. Try using different values of minsup, such as 0.5, 0.1, 0.05, 0.02, 0.01. How many results do you
# obtain as minsup varies?

# %%
from mlxtend.frequent_patterns import fpgrowth
fis=[]
for minsup in [0.5, 0.1, 0.05, 0.02, 0.01]:    
    fi = fpgrowth(df, minsup, use_colnames=True)
    print(len(fi))
    #print(fi.to_string())
    fis.append(fi)
#To get the corrisponding itemsets use "use_colnames=True"
# Out:
# 0
# 3
# 34
# 382
# 1923

# %% [markdown]
# As the *minsup* lovers the number of frequent itemset increase

# %% [markdown]
# **5 - minsup = 0.02**
#
# Consider the itemsets extracted for minsup = 0.02. How many items are contained? Which ones would you be considered the most useful?

# %%
print("Number of itemset with minsup=0.02:",len(fis[3]))
# Out:
# Number of itemset with minsup=0.02: 382

# %%
fis[3].sort_values('support', ascending = False)
# Out:
#       support                              itemsets
# 0    0.113820  (WHITE HANGING HEART T-LIGHT HOLDER)
# 68   0.105359             (JUMBO BAG RED RETROSPOT)
# 166  0.100171            (REGENCY CAKESTAND 3 TIER)
# 238  0.084911                       (PARTY BUNTING)
# 30   0.078767             (LUNCH BAG RED RETROSPOT)
# ..        ...                                   ...
# 94   0.020246         (CHICK GREY HOT WATER BOTTLE)
# 291  0.020195           (VINTAGE CHRISTMAS BUNTING)
# 213  0.020095          (FOUR HOOK  WHITE LOVEBIRDS)
# 57   0.020044            (VINTAGE SNAKES & LADDERS)
# 110  0.020044     (CANDLEHOLDER PINK HANGING HEART)
#
# [382 rows x 2 columns]

# %% [markdown]
# **6 - Association Rule Mining (*minsup* = 0.02)**

# %%
from mlxtend.frequent_patterns import association_rules
res = association_rules(fi, metric = "confidence", min_threshold=0.7)
res1 = res[["antecedents", "consequents", "support", "confidence", "lift"]]
res1
#if you want to filter on the confidence
#res2 = res1[res1["confidence"]>=0.7]
# Out:
#                                            antecedents  \
# 0                          (POPPY'S PLAYHOUSE KITCHEN)
# 1                          (POPPY'S PLAYHOUSE BEDROOM)
# 2    (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 3    (JUMBO BAG PINK POLKADOT, LUNCH BAG RED RETROS...
# 4    (JUMBO BAG PINK POLKADOT, JUMBO STORAGE BAG SUKI)
# ..                                                 ...
# 288                           (REGENCY TEA PLATE PINK)
# 289                (GARDENERS KNEELING PAD CUP OF TEA)
# 290                 (SET OF 3 WOODEN TREE DECORATIONS)
# 291                 (SET OF 3 WOODEN TREE DECORATIONS)
# 292                 (SET OF 6 SNACK LOAF BAKING CASES)
#
#                                            consequents   support  confidence  \
# 0                          (POPPY'S PLAYHOUSE BEDROOM)  0.015763    0.717890
# 1                          (POPPY'S PLAYHOUSE KITCHEN)  0.015763    0.739953
# 2                           (ALARM CLOCK BAKELIKE RED)  0.015763    0.748804
# 3                            (JUMBO BAG RED RETROSPOT)  0.012540    0.770898
# 4                            (JUMBO BAG RED RETROSPOT)  0.020800    0.801942
# ..                                                 ...       ...         ...
# 288  (REGENCY TEA PLATE GREEN, REGENCY TEA PLATE RO...  0.012842    0.836066
# 289                 (GARDENERS KNEELING PAD KEEP CALM)  0.027498    0.720317
# 290              (SET OF 3 WOODEN STOCKING DECORATION)  0.011029    0.747440
# 291                (SET OF 3 WOODEN HEART DECORATIONS)  0.010627    0.720137
# 292                (SET OF 12 FAIRY CAKE BAKING CASES)  0.012742    0.714689
#
#           lift
# 0    33.698397
# 1    33.698397
# 2    14.146764
# 3     7.316896
# 4     7.611547
# ..         ...
# 288  52.040495
# 289  15.665506
# 290  46.524057
# 291  32.132653
# 292  25.708098
#
# [293 rows x 5 columns]

# %% [markdown]
# **7 - Association rules (*minsup* = 0.01)**

# %%
fi = fis[4]
print(len(fi))
#print(fi.to_string())
res = association_rules(fi, metric = "confidence", min_threshold=0.85)
res1 = res[["antecedents", "consequents", "support", "confidence", "lift"]]
res1
# Out:
# 1923
#                                           antecedents  \
# 0   (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG PIN...
# 1   (STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK ...
# 2   (STRAWBERRY CHARLOTTE BAG, CHARLOTTE BAG PINK ...
# 3   (WOODLAND CHARLOTTE BAG, STRAWBERRY CHARLOTTE ...
# 4   (WOODLAND CHARLOTTE BAG, STRAWBERRY CHARLOTTE ...
# 5   (WOODLAND CHARLOTTE BAG, STRAWBERRY CHARLOTTE ...
# 6   (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...
# 7   (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 8                                  (HERB MARKER MINT)
# 9                                 (HERB MARKER BASIL)
# 10                             (HERB MARKER ROSEMARY)
# 11                                (HERB MARKER BASIL)
# 12                                 (HERB MARKER MINT)
# 13                             (HERB MARKER ROSEMARY)
# 14                              (HERB MARKER PARSLEY)
# 15                             (HERB MARKER ROSEMARY)
# 16                              (HERB MARKER PARSLEY)
# 17                                 (HERB MARKER MINT)
# 18                              (HERB MARKER PARSLEY)
# 19                                (HERB MARKER BASIL)
# 20                             (HERB MARKER ROSEMARY)
# 21                                (HERB MARKER THYME)
# 22                              (HERB MARKER PARSLEY)
# 23                                (HERB MARKER THYME)
# 24                                (HERB MARKER BASIL)
# 25                                (HERB MARKER THYME)
# 26                                 (HERB MARKER MINT)
# 27                                (HERB MARKER THYME)
# 28        (HERB MARKER PARSLEY, HERB MARKER ROSEMARY)
# 29           (HERB MARKER PARSLEY, HERB MARKER THYME)
# 30          (HERB MARKER ROSEMARY, HERB MARKER THYME)
# 31                              (HERB MARKER PARSLEY)
# 32                                (HERB MARKER THYME)
# 33          (HERB MARKER ROSEMARY, HERB MARKER BASIL)
# 34             (HERB MARKER THYME, HERB MARKER BASIL)
# 35          (HERB MARKER ROSEMARY, HERB MARKER THYME)
# 36  (JUMBO BAG WOODLAND ANIMALS, JUMBO SHOPPER VIN...
# 37  (WOODLAND CHARLOTTE BAG, CHARLOTTE BAG SUKI DE...
# 38      (JUMBO BAG RED RETROSPOT, SUKI  SHOULDER BAG)
# 39       (JAM MAKING SET PRINTED, SUKI  SHOULDER BAG)
# 40       (JUMBO STORAGE BAG SUKI, SUKI  SHOULDER BAG)
# 41  (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN HE...
# 42  (POPPY'S PLAYHOUSE KITCHEN, POPPY'S PLAYHOUSE ...
# 43  (POPPY'S PLAYHOUSE BEDROOM, POPPY'S PLAYHOUSE ...
# 44               (BEADED CRYSTAL HEART PINK ON STICK)
# 45  (PINK REGENCY TEACUP AND SAUCER, REGENCY CAKES...
# 46  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 47  (PINK REGENCY TEACUP AND SAUCER, REGENCY CAKES...
# 48  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 49  (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...
# 50  (CHARLOTTE BAG APPLES DESIGN, CHARLOTTE BAG PI...
# 51  (REGENCY TEA PLATE ROSES, GREEN REGENCY TEACUP...
# 52  (REGENCY TEA PLATE ROSES, GREEN REGENCY TEACUP...
# 53  (ROSES REGENCY TEACUP AND SAUCER, REGENCY TEA ...
# 54  (ROSES REGENCY TEACUP AND SAUCER, REGENCY TEA ...
# 55                           (REGENCY TEA PLATE PINK)
# 56                           (REGENCY TEA PLATE PINK)
# 57  (REGENCY TEA PLATE GREEN, REGENCY TEA PLATE PINK)
# 58  (REGENCY TEA PLATE ROSES, REGENCY TEA PLATE PINK)
#
#                                     consequents   support  confidence  \
# 0                     (JUMBO BAG RED RETROSPOT)  0.010375    0.872881
# 1                 (RED RETROSPOT CHARLOTTE BAG)  0.016418    0.860158
# 2                 (RED RETROSPOT CHARLOTTE BAG)  0.012339    0.904059
# 3                 (RED RETROSPOT CHARLOTTE BAG)  0.012188    0.920152
# 4                 (RED RETROSPOT CHARLOTTE BAG)  0.010274    0.918919
# 5                 (RED RETROSPOT CHARLOTTE BAG)  0.013094    0.858086
# 6                     (JUMBO BAG RED RETROSPOT)  0.013497    0.867314
# 7               (SET/6 RED SPOTTY PAPER PLATES)  0.013346    0.895270
# 8                           (HERB MARKER BASIL)  0.010475    0.866667
# 9                            (HERB MARKER MINT)  0.010475    0.859504
# 10                          (HERB MARKER BASIL)  0.010778    0.891667
# 11                       (HERB MARKER ROSEMARY)  0.010778    0.884298
# 12                       (HERB MARKER ROSEMARY)  0.010677    0.883333
# 13                           (HERB MARKER MINT)  0.010677    0.883333
# 14                       (HERB MARKER ROSEMARY)  0.010828    0.903361
# 15                        (HERB MARKER PARSLEY)  0.010828    0.895833
# 16                           (HERB MARKER MINT)  0.010677    0.890756
# 17                        (HERB MARKER PARSLEY)  0.010677    0.883333
# 18                          (HERB MARKER BASIL)  0.010677    0.890756
# 19                        (HERB MARKER PARSLEY)  0.010677    0.876033
# 20                          (HERB MARKER THYME)  0.011130    0.920833
# 21                       (HERB MARKER ROSEMARY)  0.011130    0.932489
# 22                          (HERB MARKER THYME)  0.010727    0.894958
# 23                        (HERB MARKER PARSLEY)  0.010727    0.898734
# 24                          (HERB MARKER THYME)  0.010576    0.867769
# 25                          (HERB MARKER BASIL)  0.010576    0.886076
# 26                          (HERB MARKER THYME)  0.010375    0.858333
# 27                           (HERB MARKER MINT)  0.010375    0.869198
# 28                          (HERB MARKER THYME)  0.010224    0.944186
# 29                       (HERB MARKER ROSEMARY)  0.010224    0.953052
# 30                        (HERB MARKER PARSLEY)  0.010224    0.918552
# 31    (HERB MARKER ROSEMARY, HERB MARKER THYME)  0.010224    0.852941
# 32  (HERB MARKER PARSLEY, HERB MARKER ROSEMARY)  0.010224    0.856540
# 33                          (HERB MARKER THYME)  0.010073    0.934579
# 34                       (HERB MARKER ROSEMARY)  0.010073    0.952381
# 35                          (HERB MARKER BASIL)  0.010073    0.904977
# 36                    (JUMBO BAG RED RETROSPOT)  0.010929    0.854331
# 37                (RED RETROSPOT CHARLOTTE BAG)  0.012641    0.859589
# 38                             (DOTCOM POSTAGE)  0.012540    0.882979
# 39                             (DOTCOM POSTAGE)  0.010526    0.958716
# 40                             (DOTCOM POSTAGE)  0.010173    0.859574
# 41         (WOODEN STAR CHRISTMAS SCANDINAVIAN)  0.011634    0.927711
# 42                  (POPPY'S PLAYHOUSE BEDROOM)  0.011281    0.854962
# 43                  (POPPY'S PLAYHOUSE KITCHEN)  0.011281    0.861538
# 44                             (DOTCOM POSTAGE)  0.010123    0.975728
# 45            (GREEN REGENCY TEACUP AND SAUCER)  0.017274    0.875000
# 46            (GREEN REGENCY TEACUP AND SAUCER)  0.015159    0.909366
# 47            (ROSES REGENCY TEACUP AND SAUCER)  0.015159    0.877551
# 48            (GREEN REGENCY TEACUP AND SAUCER)  0.027297    0.904841
# 49            (ROSES REGENCY TEACUP AND SAUCER)  0.027297    0.856240
# 50                (RED RETROSPOT CHARLOTTE BAG)  0.010778    0.859438
# 51            (ROSES REGENCY TEACUP AND SAUCER)  0.010224    0.906250
# 52                    (REGENCY TEA PLATE GREEN)  0.010123    0.897321
# 53                    (REGENCY TEA PLATE ROSES)  0.010425    0.907895
# 54            (GREEN REGENCY TEACUP AND SAUCER)  0.010073    0.877193
# 55                    (REGENCY TEA PLATE GREEN)  0.014001    0.911475
# 56                    (REGENCY TEA PLATE ROSES)  0.013548    0.881967
# 57                    (REGENCY TEA PLATE ROSES)  0.012842    0.917266
# 58                    (REGENCY TEA PLATE GREEN)  0.012842    0.947955
#
#          lift
# 0    8.284862
# 1   16.517702
# 2   17.360731
# 3   17.669768
# 4   17.646087
# 5   16.477903
# 6    8.232020
# 7   33.731473
# 8   71.109642
# 9   71.109642
# 10  73.160882
# 11  73.160882
# 12  73.081111
# 13  73.081111
# 14  74.738095
# 15  74.738095
# 16  73.695238
# 17  73.695238
# 18  73.086187
# 19  73.086187
# 20  77.147961
# 21  77.147961
# 22  74.980108
# 23  74.980108
# 24  72.702165
# 25  72.702165
# 26  71.911674
# 27  71.911674
# 28  79.104465
# 29  78.849139
# 30  76.633484
# 31  76.633484
# 32  79.104465
# 33  78.299617
# 34  78.793651
# 35  74.253020
# 36   8.108791
# 37  16.506770
# 38  24.763313
# 39  26.887368
# 40  24.106936
# 41  35.977786
# 42  40.132676
# 43  39.235568
# 44  27.364489
# 45  17.117241
# 46  17.789520
# 47  16.345828
# 48  17.701016
# 49  15.948878
# 50  16.503865
# 51  16.880394
# 52  46.764342
# 53  40.510467
# 54  17.160142
# 55  47.501984
# 56  39.353575
# 57  40.928623
# 58  49.403155
